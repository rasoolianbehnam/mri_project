# %%
# %load_ext autoreload
# %autoreload 2
from mri_project.custom_imports import *

# %%
root = "../data/images_with_predictions_v04"
files = glob.glob(root+"/*data")
file = np.random.choice(files)

# %%
data = joblib.load(file)

# %%
plt.subplots(figsize=(10, 10))
plt.imshow(data.traced_multilabel_mask)

# %%
data.get_traced_contours(90)
data.get_predicted_contours(90)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))
axes[0].imshow(data.traced_lever_arm_images[90])
axes[1].imshow(data.predicted_lever_arm_images[90])

# %%
data.traced_features
# Out:
# {'lever_arm_90': {1: 0.49938716226215046,
#   2: 7.512869361716854,
#   3: 7.5553836532484535,
#   4: 4.7703006824564005,
#   5: 3.848527514078491,
#   6: 3.692880407007107,
#   7: 4.299318787007615,
#   8: 4.394673755240038,
#   9: 4.847441446888432,
#   10: 11.21489845800174,
#   11: 10.535564100937012}}

# %%
data.predicted_features
# Out:
# {'lever_arm_90': {1: 0.05354824652889122,
#   2: 7.788744511060856,
#   3: 7.905381872310248,
#   4: 4.243098047864238,
#   5: 3.6975385180251426,
#   6: 3.981969301710265,
#   7: 4.165848767259999,
#   8: 4.5129562181815706,
#   9: 5.047845669316378,
#   10: 10.978952547515439,
#   11: 10.63555755289174}}
